# %%
# %%sql
# SELECT * FROM users WHERE age > 30;

# %%
# %%bqt
# SELECT name, score FROM dataset.leaderboard WHERE score > 1000;

# %%
# %%bash
# echo 'Hello from Bash!'
# ls -l

# %%
# %%sh
# pwd
# whoami

# %%
# %%script bash
# for i in {1..5}; do echo "Number: $i"; done

# %%
# %%javascript
# console.log('Hello from JavaScript');

# %%
# %%js
# document.body.innerHTML += '<h2>Added by JS</h2>';

# %%
# %%html
# <form><input type='text' placeholder='Enter name'><button>Submit</button></form>

# %%
# %%html
# <table border='1'><tr><th>Name</th><th>Age</th></tr><tr><td>Alice</td><td>30</td></tr></table>

# %%
# %%css
# body { background-color: lightblue; }

# %%
# %%css
# table { border-collapse: collapse; } th, td { padding: 10px; }

# %%
# %%r
# data <- data.frame(Name=c('Alice', 'Bob'), Age=c(30, 25))
# print(data)

# %%
# %%r
# hist(c(1,2,3,3,2,1,4,5,6), col='blue', main='Sample Histogram')
