# %% [markdown]
# this is `@decorator.followup` in backticks

# %% [markdown]
# this is @decorator.followup plain

# %% [markdown]
# this is *@decorator.followup* italics

# %% [markdown]
# this is bold __@decorator.followup__

# %% [markdown]
# this is bold __@decorator with spaces__

# %% [markdown]
# this is a legit email info@gmail.com

# %% [markdown]
# This is standard [google url](google.com)

# %% [markdown]
# This email in brackets should still be highlighted in ReviewNB <user@google.com> as we have not edited autolink regex in marked

# %% [markdown]
# This is a standard URL: http://example.com
#
# This is a secure URL: https://github.com
#
# This is www-only URL: www.wikipedia.org
#
# This link has a path: https://docs.python.org/3/tutorial/
#
# This link has query parameters: https://www.google.com/search?q=markdown
#
# This link has special characters: https://example.com/path_(with)_parentheses
#
# This is a domain with a port: http://localhost:8080
#
# This is a URL with authentication: http://user:pass@example.com
#
# This is a link surrounded by text before http://middle.example.com and after.
#
# This is a URL with a fragment identifier: https://developer.mozilla.org/en-US#content
#
# This is a URL with an @ in the path: https://example.com/user@domain/profile
