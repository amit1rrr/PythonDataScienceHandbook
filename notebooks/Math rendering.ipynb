# %% [markdown]
# Simple inline math $ x = 5 $ in paragraph
#
# Display math block $$ E = mc^2 $$
#
# Math with underscore $ x_i = y_j $ subscripts
#
# Math with asterisk $ x * y = z $ multiplication
#
# Complex fraction $ \\frac{a}{b} = \\frac{c}{d} $ equation
#
# Multiple inline $ a = 1 $ and $ b = 2 $ expressions
#
# Greek letters $ \\alpha + \\beta = \\gamma $ formula
